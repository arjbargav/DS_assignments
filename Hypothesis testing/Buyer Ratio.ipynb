# %% [markdown]
# ![image.png](attachment:4fa240ab-5c98-4ae9-9831-4064e2eccba1.png)

# %%
import pandas as pd
import scipy.stats as sc

# %%
df = pd.read_csv('BuyerRatio.csv')
df
# Out:
#   Observed Values  East  West  North  South
# 0           Males    50   142    131     70
# 1         Females   435  1523   1356    750

# %%
alpha = 0.05

observed = [
    [50, 435],   # [Male, Female]
    [142, 1523],
    [131, 1356],
    [70, 750]
]
observed
# Out:
# [[50, 435], [142, 1523], [131, 1356], [70, 750]]

# %%
chi2, p, dof, expected = sc.chi2_contingency(observed)

p, alpha
# Out:
# (0.6603094907091882, 0.05)

# %% [markdown]
# ## p-value > alpha, hence we fail to reject Null Hypothesis
#
# ## Ratios are similar across the 4 regions
